# %% [markdown]
# ### Q1: Questions about PyMC...
#
# Complete this formatted markdown listing of the contents of "PyMC Example Gallery". *Include links and your favorite image (right click and "copy image address") from each page.*
#
#
# #### Introductory
#
# - [General Overview](https://www.pymc.io/projects/docs/en/stable/learn/core_notebooks/pymc_overview.html)
# - [Simple Linear Regression](https://www.pymc.io/projects/docs/en/stable/learn/core_notebooks/GLM_linear.html)
# - [General API quickstart](https://www.pymc.io/projects/examples/en/latest/introductory/api_quickstart.html)
#
# | | | |
# |-|-|-|
# |![](https://www.pymc.io/projects/docs/en/stable/_images/ac30f30b2297ec4f2bb798b4f28d2cbba2d0502dbaae4a5f78fdd5cccacda517.svg)|<img src="https://www.pymc.io/projects/docs/en/stable/_images/a8276d1222c43c061dbfff6fa3ff3af15b86038fd7d1e204c429ae3714ea1a20.png"  width="500"/>|![](https://www.pymc.io/projects/examples/en/latest/_images/434538d8660bf2399ebf9df11cbd2b7cec62d8abafc588da625315074b628118.png)|
#
# #### Library Fundamentals
#
# - [Distribution Dimensionality](https://www.pymc.io/projects/docs/en/stable/learn/core_notebooks/dimensionality.html#dimensionality)
# - [PyMC and PyTensor](https://www.pymc.io/projects/docs/en/stable/learn/core_notebooks/pymc_pytensor.html#pymc-pytensor)
# - [Using Data Containers](https://www.pymc.io/projects/examples/en/latest/fundamentals/data_container.html)
#
# | ![image.png](https://www.pymc.io/projects/docs/en/stable/_images/e168299820827b4d2d2fe7deb7ad39021d3e27263f160111f6a968ae060a71fd.svg)| ![image.png](https://raw.githubusercontent.com/pymc-devs/pytensor/main/doc/tutorial/apply.png)|![image.png](https://www.pymc.io/projects/examples/en/latest/_images/e84fba8908ce2dbfc366050d8853911d674afeffc281841f8609691a3f218599.svg)|
# |-|-|-|
#
#
# #### How to
#
# - 1. [Prior and Posterior Predictive Checks](https://www.pymc.io/projects/docs/en/stable/learn/core_notebooks/posterior_predictive.html#posterior-predictive)
# - 2. [Model Comparison](https://www.pymc.io/projects/docs/en/stable/learn/core_notebooks/model_comparison.html#model-comparison)
# - 3. [Updating Priors](https://www.pymc.io/projects/examples/en/latest/howto/updating_priors.html)
# - 4. [Automatic marginalization if discrete variables](https://www.pymc.io/projects/examples/en/latest/howto/marginalizing-models.html)
# - 5. [How to debug a model](https://www.pymc.io/projects/examples/en/latest/howto/howto_debugging.html)
# - 6. [How to wrap a JAX function for us in PyMC](https://www.pymc.io/projects/examples/en/latest/howto/wrapping_jax_function.html)
# - 7. [Splines](https://www.pymc.io/projects/examples/en/latest/howto/spline.html)
# - 8. [Bayesian copula estimation: Describing correlated joing distributions](https://www.pymc.io/projects/examples/en/latest/howto/copula-estimation.html)
# - 9. [Using ModelBuilder class for deploying PyMC models](https://www.pymc.io/projects/examples/en/latest/howto/model_builder.html)
# - 10. [Using a "black box" likelihood function](https://www.pymc.io/projects/examples/en/latest/howto/blackbox_external_likelihood_numpy.html)
# - 11. [LKJ Cholesky Covariance Priors for Multivariate Normal Models](https://www.pymc.io/projects/examples/en/latest/howto/LKJ.html)
# - 12. [Bayesian Missing Data Imputation](https://www.pymc.io/projects/examples/en/latest/howto/Missing_Data_Imputation.html)
# - 13. [Profiling](https://www.pymc.io/projects/examples/en/latest/howto/profiling.html)
#
#
#
# |   |   |   |   |
# |----|----|----|----|
# | ![Image 1](https://www.pymc.io/projects/docs/en/stable/_images/c30ae812111d855935f054a90acba02cf89c774df6cfb0e6a5f08bccafb47b3e.png) | ![Image 2](https://www.pymc.io/projects/docs/en/stable/_images/220695e8447f0651dc133a3389ef5d6f586b78e08421f0a2371928118cc909f1.png) | ![Image 3](https://www.pymc.io/projects/examples/en/latest/_images/5c91b2b45e4e07be744bd90c92793f4b064b85ea9e147b0eaf3b463e1735f34a.png) | ![Image 4](https://www.pymc.io/projects/examples/en/latest/_images/f2e0b2da5798ac3e36eefd978b3243dff9d416afe6fb3017948a3c350b798c67.png) |
# | ![Image 5](https://www.pymc.io/projects/examples/en/latest/_images/cd8d49dd3519e25c0ec2d3ef30a0816fe9c3f7708d9eda15d157590da6ca27b5.svg) | ![Image 6](https://www.pymc.io/projects/examples/en/latest/_images/810705521c6d764cc52621beb88fb0f1160e1a92c804d6708c7c4f84aa34a535.png) | ![Image 7](https://www.pymc.io/projects/examples/en/latest/_images/54e57a5cb9105a0886fd8ba529ff3ab061df512bb8b8a1213bc77d097903e559.png) | ![Image 8](https://www.pymc.io/projects/examples/en/latest/_images/copula_schematic.png) |
# | ![Image 9](https://www.pymc.io/projects/examples/en/latest/_images/bbc4da85106ec9c236813f170272c9b249e0a8af0911c428cddbf54bb0752c74.png) | ![Image 10](https://www.pymc.io/projects/examples/en/latest/_images/89d287d9670af4425b66d6628cb61fdc0bb529c85ad580476b447435ab476fcc.png) | ![Image 11](https://www.pymc.io/projects/examples/en/latest/_images/f859e4ca959a1c0fc8f886a6752ef8317cff5016e94dc17a7c1cc6ac2cd9535f.png) | ![Image 12](https://www.pymc.io/projects/examples/en/latest/_images/4651aee3b14cc8fcb4f416403736e3ecb5f7f8ce1171367a38f6c44a02888f86.png) |
# | ![Image 13](https://www.pymc.io/projects/examples/en/latest/_static/PyMC.png) |    |    |    |
#
#
# #### Generalized Linear Models
#
# - 1. [GLM: Robust Linear Regression](https://www.pymc.io/projects/examples/en/latest/generalized_linear_models/GLM-robust.html)
# - 2. [GLM-ordinal-features](https://www.pymc.io/projects/examples/en/latest/generalized_linear_models/GLM-ordinal-features.html)
# - 3. [Out-of-Sample Predictions](https://www.pymc.io/projects/examples/en/latest/generalized_linear_models/GLM-out-of-sample-predictions.html)
# - 4. [Bayesian regression with truncated or censored data](https://www.pymc.io/projects/examples/en/latest/generalized_linear_models/GLM-truncated-censored-regression.html)
# - 5. [Binomial regression](https://www.pymc.io/projects/examples/en/latest/generalized_linear_models/GLM-binomial-regression.html)
# - 6. [GLM: Negative Bionmial Regression](https://www.pymc.io/projects/examples/en/latest/generalized_linear_models/GLM-negative-binomial-regression.html)
# - 7. [Hierarchical Binomial Model: Rat Tumor Example](https://www.pymc.io/projects/examples/en/latest/generalized_linear_models/GLM-hierarchical-binomial-model.html)
# - 8. [Primer on Bayesian Methods of Multilevel Modeling](https://www.pymc.io/projects/examples/en/latest/generalized_linear_models/multilevel_modeling.html)
# - 9. [GLM-missing-values-in-covariates](https://www.pymc.io/projects/examples/en/latest/generalized_linear_models/GLM-missing-values-in-covariates.html)
# - 10. [Regression Models with Ordered Categorical Outcomes](https://www.pymc.io/projects/examples/en/latest/generalized_linear_models/GLM-ordinal-regression.html)
# - 11. [GLM: Poisson Regression](https://www.pymc.io/projects/examples/en/latest/generalized_linear_models/GLM-poisson-regression.html)
# - 12. [Discrete Choice and Random Utility Models](https://www.pymc.io/projects/examples/en/latest/generalized_linear_models/GLM-discrete-choice_models.html)
# - 13. [GLM: Model Selection](https://www.pymc.io/projects/examples/en/latest/generalized_linear_models/GLM-model-selection.html)
# - 14. [GLM: Robust Regression using Custom Likelihood for Outlier Classification](https://www.pymc.io/projects/examples/en/latest/generalized_linear_models/GLM-robust-with-outlier-detection.html)
# - 15. [Roling Regression](https://www.pymc.io/projects/examples/en/latest/generalized_linear_models/GLM-rolling-regression.html)
#
#
# |   |   |   |   |
# |----|----|----|----|
# | ![Image 1](https://www.pymc.io/projects/examples/en/latest/_images/cca03e23e9627b2fb5f4156cb11fa372d2c3f72389827aa6cfb4f0503abc80ab.png) | ![Image 2](https://www.pymc.io/projects/examples/en/latest/_images/a2ebaab5ad80818b83df814fb6301e97b197054bb847e8dda7c3dc4967ec36ee.png) | ![Image 3](https://www.pymc.io/projects/examples/en/latest/_images/300d0cf80648831ccb0009c099225a7540f30c1fc7e80e3cd24f2dcaf375f6bd.png) | ![Image 4](https://www.pymc.io/projects/examples/en/latest/_images/833e85c397967de588409136ca9a0f916f3c8fe280acfe1897c235914af7a2be.png) |
# | ![Image 5](https://www.pymc.io/projects/examples/en/latest/_images/47b2df508c92dc27eed40a33b0d251d3b893b2509296aaf89312352c4cbf31c5.png) | ![Image 6](https://www.pymc.io/projects/examples/en/latest/_images/26e650782d73f95310b3fda053366e4f2a9df307cc35e9ed09f3a2fecc1ed06d.png) | ![Image 7](https://www.pymc.io/projects/examples/en/latest/_images/02876264b478027ad5229df6fd2030ad6b920fc7092a6c1802da60315485d3f5.png) | ![Image 8](https://www.pymc.io/projects/examples/en/latest/_images/3c9cc8c9771b4e934662b6de58d7f26b9f4fbf3004405b8458282986bbdc6d48.png) |
Spatial Data](https://www.pymc.io/projects/examples/en/latest/spatial/nyc_bym.html)
# - 2. [The prevalence of malaria in the Gambia](https://www.pymc.io/projects/examples/en/latest/spatial/malaria_prevalence.html)
# - 3. [Conditional Autoregressive Models for Spatial Data](https://www.pymc.io/projects/examples/en/latest/spatial/conditional_autoregressive_priors.html)
#
#
#
# |   |   |   |
# |----|----|----|
# | ![Image 1](https://www.pymc.io/projects/examples/en/latest/_images/e358b2dae33b327a31a314b6d384dc026c26c2982474034ecb7082b7c27ab667.png) | ![Image 2](https://www.pymc.io/projects/examples/en/latest/_images/3e2021a0d3138688f6e1c6e69b99867c6bcecaa5390ed500b9bf3530e08c7f09.png) | ![Image 3](https://www.pymc.io/projects/examples/en/latest/_images/b0c1efdbaa4abe2e3e02f1fbe1f807c3569663c0a631da625df25b897816bbe8.png) |
#
#
#
#
# #### Diagnostics and Model Criticism
#
# - 1. [Bayes Factors and Marginal Likelihood](https://www.pymc.io/projects/examples/en/latest/diagnostics_and_criticism/Bayes_factor.html)
# - 2. [Diagnosing Biased Inference with Divergences](https://www.pymc.io/projects/examples/en/latest/diagnostics_and_criticism/Diagnosing_biased_Inference_with_Divergences.html)
# - 3. [Sampler Statistics](https://www.pymc.io/projects/examples/en/latest/diagnostics_and_criticism/sampler-stats.html)
# - 4. [Model Averaging](https://www.pymc.io/projects/examples/en/latest/diagnostics_and_criticism/model_averaging.html)
#
#
# |   |   |
# |----|----|
# | ![Image 1](https://www.pymc.io/projects/examples/en/latest/_images/93c562d90c210b4eee9731f7e3adf06f4c54bf60db206322ea41262dc16c6290.png) | ![Image 2](https://www.pymc.io/projects/examples/en/latest/_images/6abc61d5384d6fa08f664dc8adfc9e0f5ce5ddf17c576cae88342857e33377e4.png) |
# | ![Image 3](https://www.pymc.io/projects/examples/en/latest/_images/a504e1bc44836e2d0f52990a78663d6905f9244b81eacd95d656211c3fc8910e.png) | ![Image 4](https://www.pymc.io/projects/examples/en/latest/_images/04dfc13dad24652049eae900d067708b33c326a1cc0a809d54446806b8c88fe5.png) |
#
#
#
#
# #### Bayesian Additive Regression Trees
#
# - 1. [Categorical regression](https://www.pymc.io/projects/examples/en/latest/bart/bart_categorical_hawks.html)
# - 2. [Bayesian Additive Regression Trees: Introduction](https://www.pymc.io/projects/examples/en/latest/bart/bart_introduction.html)
# - 3. [Modeling Heteroscedasticity with BART](https://www.pymc.io/projects/examples/en/latest/bart/bart_heteroscedasticity.html)
# - 4. [Quantile Regression with BART](https://www.pymc.io/projects/examples/en/latest/bart/bart_quantile_regression.html)
#
#
# |   |   |
# |----|----|
# | ![Image 1](https://www.pymc.io/projects/examples/en/latest/_images/5aef36de4f892b86b3c20ec45bf0f3b04c6732fe7ae87bb3c358e72362e34e60.png) | ![Image 2](https://www.pymc.io/projects/examples/en/latest/_images/799c9ad4685dcfcd9174007a8904d3fb4151861c2e66f93005878b67d6bdd470.png) |
# | ![Image 3](https://www.pymc.io/projects/examples/en/latest/_images/2a70660877b52a1474f190519f6d49f2a352f6ee88cc7578c0df40439f737732.png) | ![Image 4](https://www.pymc.io/projects/examples/en/latest/_images/db057b16cc6507be0bf4e84b884be162f7f37c6622887347e3b616418e3b79fe.png) |
#
#
#
# #### Mixture Models
#
# - 1. [Gaussian Mixture Model](https://www.pymc.io/projects/examples/en/latest/mixture_models/gaussian_mixture_model.html)
# - 2. [Dependent density regression](https://www.pymc.io/projects/examples/en/latest/mixture_models/dependent_density_regression.html)
# - 3. [Dirichlet process mixtures for density estimation](https://www.pymc.io/projects/examples/en/latest/mixture_models/dp_mix.html)
# - 4. [Marginalized Gaussian Mixture Model](https://www.pymc.io/projects/examples/en/latest/mixture_models/marginalized_gaussian_mixture_model.html)
# - 5. [Dirichlet mixtures of multinomials](https://www.pymc.io/projects/examples/en/latest/mixture_models/dirichlet_mixture_of_multinomials.html)
#
#
# |   |   |   |
# |----|----|----|
# | ![Image 1](https://www.pymc.io/projects/examples/en/latest/_images/1c7c5303d6f30869cfe061a28ff09060db0019f1c0c5f73bad0d4a60deba0e39.png) | ![Image 2](https://www.pymc.io/projects/examples/en/latest/_images/d394806a5d839fa0fa678227efd4e541486045dcdfb4a555b3749705848427b1.png) | ![Image 3](https://www.pymc.io/projects/examples/en/latest/_images/eb4d5d50b995d0b987d681aa0e77af7dc7061e01fcf76bc05a146b3b32f5fb52.png) |
# | ![Image 4](https://www.pymc.io/projects/examples/en/latest/_images/78c1e0fce5edbb98b0ec688260fc58aca71e01953b0d1a0e60e39968ebc1d20f.png) | ![Image 5](https://www.pymc.io/projects/examples/en/latest/_images/4079c3b8a96e0f355d970e171eed03a135ce5a437b463bf586120aaa1c09226e.png) |    |
#
#
# #### Survivial Analysis
# - 1. [Reparameterizing the Weibull Accelerated Failure Time Model](https://www.pymc.io/projects/examples/en/latest/survival_analysis/weibull_aft.html)
# - 2. [Bayesian Survival Analysis](https://www.pymc.io/projects/examples/en/latest/survival_analysis/survival_analysis.html)
# - 3. [Censored Data Models](https://www.pymc.io/projects/examples/en/latest/survival_analysis/censored_data.html)
# - 4. [Frailty and Survival Regression Models](https://www.pymc.io/projects/examples/en/latest/survival_analysis/frailty_models.html)
# - 5. [Bayesian Parametric Survival Analysis](https://www.pymc.io/projects/examples/en/latest/survival_analysis/bayes_param_survival.html)
#
#
# |   |   |   |
# |----|----|----|
# | ![Image 1](https://www.pymc.io/projects/examples/en/latest/_images/7e062de9dac35861a87f76119ab3ed3a249f19ef978160a757f05f50db6e6996.png) | ![Image 2](https://www.pymc.io/projects/examples/en/latest/_images/faf356a8f5bf2a21353a56a90e7fea6f2795f67b40ca3f56c59ea8ebf91971dd.png) | ![Image 3](https://www.pymc.io/projects/examples/en/latest/_images/5d33add778ae781898173c0065c76cd136bc93722573ac843c9f89db0a03f7c2.png) |
# | ![Image 4](https://www.pymc.io/projects/examples/en/latest/_images/b3e2c7af727f5d18818404da1643ee9302d42bb94b51a7e89c7d3ea73349da79.png) | ![Image 5](https://www.pymc.io/projects/examples/en/latest/_images/e802f820d9d647e7f9fa23b286e51eef84af3331c89bc927938c4a6bc3e6121e.png) |    |
#
#
#
#
#
# #### ODE models
#
# - 1. [ODE Lotka-Volterra With Bayesian Inference in Multiple Ways](https://www.pymc.io/projects/examples/en/latest/ode_models/ODE_Lotka_Volterra_multiple_ways.html)
# - 2. [Lotka-Volterra with manual gradients](https://www.pymc.io/projects/examples/en/latest/ode_models/ODE_with_manual_gradients.html)
# - 3. [pymc3.ode: Shapes and benchmarking](https://www.pymc.io/projects/examples/en/latest/ode_models/ODE_API_shapes_and_benchmarking.html)
# - 4. [GSoC 2019: Introduction of pymc3.ode API](https://www.pymc.io/projects/examples/en/latest/ode_models/ODE_API_introduction.html)
#
#
#
# |   |   |
# |----|----|
# | ![Image 1](https://www.pymc.io/projects/examples/en/latest/_images/07e77a972517df91ac84d870e9b2c42ca3c9f6f92420d84a4ef85ff0eb59d895.png) | ![Image 2](https://www.pymc.io/projects/examples/en/latest/_images/0aadec0161029b521f232bf0b6337ac91197f5866b89336db2adcc63a5634aa0.png) |
# | ![Image 3](https://www.pymc.io/projects/examples/en/latest/_images/f1d6ce0b93a1398ab102c7f009b8bf3fc988f78b54f650ccdf4b841fa78b2ea9.png) | ![Image 4](https://www.pymc.io/projects/examples/en/latest/_images/7774ceeaf7ca87d295b2921716ca9c43c4d094d1ba580111bcea6701cb4eb28e.png) |
#
#
# #### MCMC
#
# - 1. [Lasso regression with block updating](https://www.pymc.io/projects/examples/en/latest/samplers/lasso_block_update.html)
# - 2. [Approximate Bayesian Computation](https://www.pymc.io/projects/examples/en/latest/samplers/SMC-ABC_Lotka-Volterra_example.html)
# - 3. [DEMetropolis and DEMetropolis(Z) Algorithm Comparisons](https://www.pymc.io/projects/examples/en/latest/samplers/DEMetropolisZ_EfficiencyComparison.html)
# - 4. [Faster Sampling with JAX and Numba](https://www.pymc.io/projects/examples/en/latest/samplers/fast_sampling_with_jax_and_numba.html)
# - 5. [Sequential Monte Carlo](https://www.pymc.io/projects/examples/en/latest/samplers/SMC2_gaussians.html)
# - 6. [Using a custom step method for sampling from locally conjugate posterior distributions](https://www.pymc.io/projects/examples/en/latest/samplers/sampling_conjugate_step.html)
# - 7. [DEMetropolis(Z) Sampler Tuning](https://www.pymc.io/projects/examples/en/latest/samplers/DEMetropolisZ_tune_drop_fraction.html)
# - 8. [Compound Steps in Sampling](https://www.pymc.io/projects/examples/en/latest/samplers/sampling_compound_step.html)
#
#
#
# |   |   |   |
# |----|----|----|
# | ![Image 1](https://www.pymc.io/projects/examples/en/latest/_images/2bc755fd8bf0a29be0c099502d53d2097de89708e8fd4c792426392f28773e1f.png) | ![Image 2](https://www.pymc.io/projects/examples/en/latest/_images/b3dd5f2e6168f27fbc43c4de6ac4a767b9e2843abcde4fc0ac6387024cfdd936.png) | ![Image 3](https://www.pymc.io/projects/examples/en/latest/_images/fd0c52f3aa065ef4a1a53be92edc2bda2b37c207975492919379200bef6faec4.png) |
# | ![Image 4](https://www.pymc.io/projects/examples/en/latest/_images/a6200c084641fcdbddb8dcd934b79899a09357b22b12d743e338ae95127cf922.png) | ![Image 5](https://www.pymc.io/projects/examples/en/latest/_images/smc.png) | ![Image 6](https://www.pymc.io/projects/examples/en/latest/_images/aede7ed8b91855a9ffe4fdb579ab4658a52be9906f1364e0281e7af3831406de.png) |
# | ![Image 7](https://www.pymc.io/projects/examples/en/latest/_images/914473e8d0a93efa73f7e8663a32bfa84b85adb927865a9205100e98ed535789.png) | ![Image 8](https://www.pymc.io/projects/examples/en/latest/_images/c33a125122359a1dcd8709a398ea21e456e015befd1ccbd3c1fa23b8879eb33e.png) |    |
#
#
# #### Variational Inference
#
# - 1. [Variational Inference: Bayesian Neural Networks](https://www.pymc.io/projects/examples/en/latest/variational_inference/bayesian_neural_network_advi.html)
# - 2. [Pathfinder Variational Inference](https://www.pymc.io/projects/examples/en/latest/variational_inference/pathfinder.html)
# - 3. [Empirical Approximation overview](https://www.pymc.io/projects/examples/en/latest/variational_inference/empirical-approx-overview.html)
# - 4. [Introduction to Variational Inference with PyMC](https://www.pymc.io/projects/examples/en/latest/variational_inference/variational_api_quickstart.html)
# - 5. [GLM: Mini-batch ADVI on hierarchical regression model](https://www.pymc.io/projects/examples/en/latest/variational_inference/GLM-hierarchical-advi-minibatch.html)
#
#
# |   |   |   |
# |----|----|----|
# | ![Image 1](https://www.pymc.io/projects/examples/en/latest/_images/cad6382102331ff90c2c382f63af66a7275b32896cbbb27e8ff1d4210c4118a6.png) | ![Image 2](https://www.pymc.io/projects/examples/en/latest/_images/077012558f2fe2e6b21854e6182b00e824a0d3a00e6df1688d13d20081a76027.png) | ![Image 3](https://www.pymc.io/projects/examples/en/latest/_images/57f01d3caf90b26ed1a392be29a6d87a4c6a6fd537f9a2650ff983fce3f1acdb.png) |
# | ![Image 4](https://www.pymc.io/projects/examples/en/latest/_images/c9ab10539759da975aa8b8321f20f845e4fa74d348d913b339342682c4dd3aea.png) | ![Image 5](https://www.pymc.io/projects/examples/en/latest/_images/af9b90617fc072dcb41643f8d1228130d436ae7589248a7adcc8582793cf8ce3.png) |    |

# %% [markdown]
# ### Q2: Continue "Q2" of the previous weeks 3 and 4

# %%
import pymc as pm
from scipy import stats
import matplotlib.pyplot as plt
import numpy as np
import arviz as az

import logging # dir(logging) for available functionality
_log = logging.getLogger("pymc")
_log.setLevel(logging.INFO) # 20

# %%
m=1000
true_theta, true_tau = 0, 1
x_observations = stats.norm.rvs(size=m, loc=true_theta, scale=1/true_tau)

# %% [markdown]
# 1. *Use PyMC to provide Bayesian inference for the paramaters associated with a sample of normal data where your prior for theta is a normal distribution and your prior for $\tau$ is a gamma distribution. Provide diagnostic assessments of the performance of your algorithm.*

# %%
conjugate_normal_gamma = pm.Model()
with conjugate_normal_gamma:
    theta0 = 0
    theta_prior_n = 1
    tau_SS_prior = 1
    tau_prior_n = 1

    tau0 = theta_prior_n*true_tau


    theta = pm.Normal("theta", mu=theta0, sigma=tau0**(-0.5))
    tau = pm.Gamma("tau", alpha=tau_prior_n/2,
                            beta=tau_SS_prior/2)
    x_obs = pm.Normal("x_obs", mu=theta, tau=tau, observed=x_observations)

with conjugate_normal_gamma:
    idata_normal_gamma = pm.sample(draws=m, chains=2, tune=100)
# Out:
# INFO:pymc.sampling.mcmc:Initializing NUTS using jitter+adapt_diag...
# INFO:pymc.sampling.mcmc:Sequential sampling (2 chains in 1 job)
# INFO:pymc.sampling.mcmc:NUTS: [theta, tau]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# INFO:pymc.sampling.mcmc:Sampling 2 chains for 100 tune and 1_000 draw iterations (200 + 2_000 draws total) took 4 seconds.
# INFO:pymc.stats.convergence:We recommend running at least 4 chains for robust computation of convergence diagnostics

# %%
az.plot_forest(idata_normal_gamma, var_names=["theta", "tau"],
               combined=True, hdi_prob=0.95, r_hat=True)
# Out:
# array([<Axes: title={'center': '95.0% HDI'}>,
#        <Axes: title={'center': 'r_hat'}>], dtype=object)

# %%
az.plot_trace(idata_normal_gamma, var_names=["theta", "tau"])
# Out:
# array([[<Axes: title={'center': 'theta'}>,
#         <Axes: title={'center': 'theta'}>],
#        [<Axes: title={'center': 'tau'}>, <Axes: title={'center': 'tau'}>]],
#       dtype=object)

# %%
az.summary(idata_normal_gamma, round_to=5)#2)
# Out:
#           mean       sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd    ess_bulk  \
# tau    1.04540  0.04728  0.95377  1.13125    0.00113  0.00080  1752.26607
# theta -0.01765  0.03155 -0.07994  0.03835    0.00071  0.00063  1952.73191
#
#          ess_tail    r_hat
# tau    1290.77691  1.00067
# theta  1507.60250  0.99929

# %% [markdown]
# 2. *Use PyMC to provide Bayesian inference for the paramaters associated with a sample of normal data where your prior for theta is a non normal distribution and your prior for $\tau$ is a non-gamma distribution. Provide diagnostic assessments of the performance of your algorithm.*

# %%
conjugate_student_t_truncnorm = pm.Model()

with conjugate_student_t_truncnorm:
  theta0 = 0
  theta_prior_n = 1
  tau0 = theta_prior_n * true_tau

  theta = pm.StudentT('theta', mu=theta0, sigma=tau0**(-0.5), nu=2)

  tau_ss_prior = 1
  tau_prior_n = 1
  s = 5
  tau = pm.TruncatedNormal('tau', lower = -tau0/s, upper = np.inf, mu = tau0, sigma = s)

  # the likelihood
  x_obs = pm.Normal('x_obs', mu=theta, sigma=1/tau, observed=x_observations)

# %%
m=1000
with conjugate_student_t_truncnorm:
  idata_t_norm = pm.sample(draws=m, chains=2, tune=100)
# Out:
# INFO:pymc.sampling.mcmc:Initializing NUTS using jitter+adapt_diag...
# INFO:pymc.sampling.mcmc:Sequential sampling (2 chains in 1 job)
# INFO:pymc.sampling.mcmc:NUTS: [theta, tau]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# INFO:pymc.sampling.mcmc:Sampling 2 chains for 100 tune and 1_000 draw iterations (200 + 2_000 draws total) took 2 seconds.
# INFO:pymc.stats.convergence:We recommend running at least 4 chains for robust computation of convergence diagnostics

# %%
az.plot_forest(idata_t_norm, var_names=['theta', 'tau'], combined=True, hdi_prob=0.95, r_hat=True)
# Out:
# array([<Axes: title={'center': '95.0% HDI'}>,
#        <Axes: title={'center': 'r_hat'}>], dtype=object)

# %%
az.plot_trace(idata_t_norm, var_names=["theta", "tau"])
# Out:
# array([[<Axes: title={'center': 'theta'}>,
#         <Axes: title={'center': 'theta'}>],
#        [<Axes: title={'center': 'tau'}>, <Axes: title={'center': 'tau'}>]],
#       dtype=object)

# %%
az.summary(idata_t_norm, round_to=5)#2)
# Out:
#           mean       sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd    ess_bulk  \
# tau    1.02182  0.02241  0.98174  1.06451    0.00050  0.00035  2001.65804
# theta -0.01850  0.03112 -0.07581  0.04180    0.00115  0.00082   739.20371
#
#          ess_tail    r_hat
# tau    1501.44185  1.00076
# theta   879.54803  1.00371

# %% [markdown]
# 3. *Use PyMC to provide Bayesian inference for the paramaters associated with a sample of normal data where your prior for theta is a yet another different again non normal distribution and your prior for $\tau$ is a yet another different again non-gamma distribution. Provide diagnostic assessments of the performance of your algorithm.*

# %%
conjugate_laplace_exp = pm.Model()
with conjugate_laplace_exp:
    theta0 = 0
    theta_prior_n = 1
    tau0 = theta_prior_n * true_tau

    theta = pm.Laplace("theta", mu=theta0, b=1/tau0)

    tau = pm.Exponential("tau", lam=1)

    x_obs = pm.Normal('x_obs', mu=theta, sigma=1/tau, observed=x_observations)

with conjugate_laplace_exp:
    idata_laplace_exp = pm.sample(draws=m, chains=2, tune=100)
# Out:
# INFO:pymc.sampling.mcmc:Initializing NUTS using jitter+adapt_diag...
# INFO:pymc.sampling.mcmc:Sequential sampling (2 chains in 1 job)
# INFO:pymc.sampling.mcmc:NUTS: [theta, tau]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# INFO:pymc.sampling.mcmc:Sampling 2 chains for 100 tune and 1_000 draw iterations (200 + 2_000 draws total) took 2 seconds.
# INFO:pymc.stats.convergence:We recommend running at least 4 chains for robust computation of convergence diagnostics

# %%
az.plot_trace(idata_laplace_exp, var_names=["theta", "tau"])
# Out:
# array([[<Axes: title={'center': 'theta'}>,
#         <Axes: title={'center': 'theta'}>],
#        [<Axes: title={'center': 'tau'}>, <Axes: title={'center': 'tau'}>]],
#       dtype=object)

# %%
az.plot_forest(idata_laplace_exp, var_names=['theta', 'tau'], combined=True, hdi_prob=0.95, r_hat=True)
# Out:
# array([<Axes: title={'center': '95.0% HDI'}>,
#        <Axes: title={'center': 'r_hat'}>], dtype=object)

# %%
az.summary(idata_laplace_exp, round_to=5)#2)
# Out:
#           mean       sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd    ess_bulk  \
# tau    1.02253  0.02339  0.97880  1.06643    0.00052  0.00037  2046.02623
# theta -0.01531  0.02990 -0.07432  0.03741    0.00084  0.00059  1288.02450
#
#          ess_tail    r_hat
# tau    1505.68304  1.00061
# theta  1232.69397  1.00348

# %% [markdown]
# ### Q3: Slice Sampling
#
# *First explain how the Markov algorithm of slice sampling as given below works. Then explain the steps by which slice sampling could be used in place of a Metropolis-Hasting step in a Metropolis within Gibbs algorithm where the full conditionals are only known up to a normalizing constant. In your explanation clarify what the curve that we're sampling beneath is, and what the initial value and steps are to create the draw for Gibbs sampling.*

# %%
def slice_f_at_y(f, x, y, x_grid=np.linspace(0,1,51)):

    # find interval of grid points where f(x_grid) > y
    # then extend the enterval so endpoints f(a)<y and f(b)<y
    x_grid_delta = x_grid[1]-x_grid[0]
    a,b = x_grid[f(x_grid)>y][[0,-1]]+[-x_grid_delta,x_grid_delta]
    # a,b = x_grid[0,-1]  # make the interval all of x_grid

    x_ = a + stats.uniform().rvs()*(b-a)
    if f(x_)>y:
        return x_,1  # in 1 try if f(x_)>y and "x_ is under f"
    elif x_ < x:  # or if "x_ was above f on the left side of the interval"
        x_l,x_r = x_,b
    else:
        x_l,x_r = a,x_  # or if "x_ was above f on the right side of the interval"
    return slice_f_at_y_(f, x, y, x_l, x_r, tot = 2)  # try again with a reduced interval

def slice_f_at_y_(f, x, y, x_l=0, x_r=1, tot=1):

    x_ = x_l + stats.uniform().rvs()*(x_r-x_l)

    if f(x_)>y:
        return x_,tot
    elif x_ < x:
        x_l = x_
    else:
        x_r = x_
    return slice_f_at_y_(f, x, y, x_l, x_r, tot = tot+1)

# %%
x_grid = np.linspace(0,1,1000)
f = lambda x: stats.beta(1.5,3).pdf(x)
plt.plot(x_grid, f(x_grid))

m = 100
x = np.zeros([m+1,3])
x[:2,0] = 0.25

plot_trace = 10
for t in range(1,m):

    x[t,1] = stats.uniform().rvs()*f(x[t,0])
    if t < plot_trace:
        plt.plot([x[t,0]]*2, [x[t-1,1],x[t,1]], 'k')

    x[t+1,0],x[t+1,2] = slice_f_at_y(f, x[t,0], x[t,1])
    if t < plot_trace:
        if t==1:
            plt.plot([x[t,0], x[t+1,0]], [x[t,1]]*2, 'k--', label=str(plot_trace)+ " iterations")
        plt.plot([x[t,0], x[t+1,0]], [x[t,1]]*2, 'k--')

plt.hist(x[:,0], density=True, label=str(m)+" iterations\n x values only")
plt.legend();

# %% [markdown]
# 1. How the Markov algorithm of slice sampling works.
#
# The key idea of slice sampling is that it is sampling from the target distribution f(x) without specifying proposal distribution. The following are the steps for the slice sampling:
#
#     - Given the current state x_t, we sample y ~ normal(0, f(x_t)) to define a horizontal slice.
#     - Then, we determine the sampling interval
#     - sample a new x within slice.
#
# `slice_f_at_y` is the main function that finds the initial interval and extends the interval. If the sample is within the interval, it accepts, else it will call `slice_f_at_y_` to recursively sampling until the new sample is accepted.
#
# 2. Using Slice Sampling in a Metropolis-Within-Gibbs Algorithm
#
# We can replace the Metropolis-Hastings step with slice sampling to adaptively sample from the target distribution. Instead of proposing a new value and accepting/rejecting as in Metropolis-Hastings, slice sampling first draws a horizontal threshold y~unif() to define the slice. The curve represents the unnormalized full conditional distribution of the variable x given others. The initial value for slice sampling is at $x^{(t)}$ and each step is the t+1 that the sampler has to take.
